# %%
from astropy.io import fits
from astropy.table import Table

import fitsio

# %%
path = '/home/wbc/code3/llm-spectro-agent_advance/test_set/DESI/all_spectra_per_wave.fits'

hdul = fits.open(path)
tb = Table.read(path)
# Out:
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]

# %%
hdul.info()
# Out:
# Filename: /home/wbc/code3/llm-spectro-agent_advance/test_set/DESI/all_spectra_per_wave.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   ()
#   1  METADATA      1 BinTableHDU     11   40R x 1C   [K]
#   2  SPECTRA       1 BinTableHDU     23   40R x 7C   [I, PE(2751), PE(2751), PE(2326), PE(2326), PE(2881), PE(2881)]

# %%
spec = fitsio.FITS(path)

# %%
a = Table(spec['SPECTRA'].read())

# %%
a.keys()
# Out:
# ['INDEX', 'WAVE_B', 'FLUX_B', 'WAVE_R', 'FLUX_R', 'WAVE_Z', 'FLUX_Z']

# %%
# B band
