# %%
import json

# %%
path_old = '/home/wbc/code3/llm-spectro-agent/prompt_content/prompt_template.json'
with open(path_old, 'r') as f:
    prompt_old = json.load(f)

# %%
a = prompt_old['Spectral Rule Analyst']['describe_spectrum_picture']['_visual']

# %%
a.keys()
# Out:
# dict_keys(['system_prompt', 'user_prompt_continuum', 'user_prompt_lines', 'user_prompt_quality'])

# %%
print(a['system_prompt'])
# Out:
# 你是一个天文学光谱分析专家。你的任务是根据所给的信息分析未知红移的光谱。
#
# 请严格按照以下要求输出，仅回答问题，不加解释。
# 因红移未知，禁止对光谱特征（如谱线等）进行物理猜测。

# %%
print(a['user_prompt_quality'])
# Out:
# ## Step 3: 数据质量
# 你正在阅读一张从PNG中用OpenCV提取出的光谱图。
# 图中包含：
# - 蓝线：光谱信号
# - 粉红区：OpenCV导致的数据缺失
#
# 用1-2句话总结：
# - 信噪比（高/低）
# - 哪些区域数据不可靠（即哪些波长范围对应的粉红区域相对蓝色信号更加明显）？
